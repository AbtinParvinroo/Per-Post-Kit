# %%
from plotter import Plotter

x = [1,2,3,4,50,70]

p = Plotter()
p.line_plotter(x, [4,5,6,7,8,9])

# %%
from outlier import DataCleaner
import pandas as pd
df = pd.DataFrame({
    'x':[14, 7, 9, 16, 8, 50],
    'y':[5, 12, 46, 101, 11, 17]
})

dc = DataCleaner(df)
dc.clean(detect_method='iqr', replace='mean')
# Out:
# e:\Projects\Python\Processing Assistent\processor_assistent\outlier.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.333333333333332' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_cleaned.loc[mask, col] = df_cleaned[col].mean()
#            x   y
# 0  14.000000   5
# 1   7.000000  12
# 2   9.000000  46
# 3  17.333333  32
# 4   8.000000  11
# 5  17.333333  32

# %%
from feature_analysis import FeatureAnalyze

fa = FeatureAnalyze(df, df['x'], df['y'])
fa.variance(df['x'])
# Out:
# {'status': 'too high', 'variance': np.float64(223.8888888888889)}
